# %%
import pandas as pd

# %% [markdown]
# # Part 1

# %%
list_range = pd.read_csv("../DATA/Day02_InvalidID.csv")

# %%
list_range = list_range.columns.tolist()

# %%
new_list = []
num_invalid = 0
for i in range(len(list_range)):

    start, end = list_range[i].split("-")
    

    if len(start) % 2 == 0 and len(end) % 2 == 0:

        h_start = start[:(len(start) // 2)]
        h_end = end[:(len(end) // 2)]

        # range_check = int(h_end) - int(h_start) + 1

    elif len(start) % 2 != 0 and len(end) % 2 == 0:

        start = "1" + "0" * len(start)
        h_start = start[:(len(start) // 2)]
        h_end = end[:(len(end) // 2)]

    elif len(start) % 2 == 0 and len(end) % 2 != 0:

        end = "9" * (len(end) - 1)
        h_start = start[:(len(start) // 2)]
        h_end = end[:(len(end) // 2)]
    
    
    for i in range(int(h_start), int(h_end) + 1):

        # print(str(i) + str(i))

        if int(str(i) + str(i)) >= int(start) and int(str(i) + str(i)) <= int(end):

            num_invalid += int(str(i) + str(i))

    # new_list.append([start, end, len(start), len(end)])
# Out:
# 3737337373
# 3737437374
# 5858558585
# 5858658586
# 166166
# 167167
# 168168
# 169169
# 170170
# 171171
# 172172
# 173173
# 174174
# 175175
# 176176
# 177177
# 178178
# 179179
# 180180
# 181181
# 182182
# 183183
# 184184
# 185185
# 186186
# 187187
# 188188
# 189189
# 190190
# 191191
# 192192
# 193193
# 194194
# 195195
# 196196
# 197197
# 198198
# 199199
# 200200
# 201201
# 202202
# 203203
# 204204
# 205205
# 206206
# 207207
# 208208
# 209209
# 210210
# 211211
# 212212
# 213213
# 214214
# 215215
# 216216
# 217217
# 218218
# 219219
# 220220
# 221221
# 222222
# 223223
# 224224
# 225225
# 226226
# 227227
# 228228
# 229229
# 230230
# 231231
# 232232
# 233233
# 234234
# 235235
# 236236
# 15321532
# 15331533
# 15341534
# 15351535
# 15361536
# 15371537
# 15381538
# 15391539
# 15401540
# 15411541
# 15421542
# 753753
# 754754
# 755755
# 756756
# 757757
# 758758
# 759759
# 760760
# 761761
# 762762
# 763763
# 764764
# 765765
# 766766
# 767767
# 768768
# 769769
# 770770
# 771771
# 772772
# ...

# %%
num_invalid
# Out:
# 38437576669

# %% [markdown]
# # Part 2
